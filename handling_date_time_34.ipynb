# %%
import numpy as np
import pandas as pd

# %%
date = pd.read_csv('orders.csv')
time = pd.read_csv('messages.csv')

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
time.head()
# Out:
#                   date                                                msg
# 0  2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1  2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2  2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3  2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4  2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше

# %% [markdown]
# # working with dates dataset first

# %%
date.head()
# Out:
#          date  product_id  city_id  orders
# 0  2019-12-10        5628       25       3
# 1  2018-08-15        3646       14     157
# 2  2018-10-23        1859       25       1
# 3  2019-08-17        7292       25       1
# 4  2019-01-06        4344       25       3

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   object
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: int64(3), object(1)
# memory usage: 31.4+ KB

# %%
date.isnull().sum()
# Out:
# date          0
# product_id    0
# city_id       0
# orders        0
# dtype: int64

# %%
# we can  see that there is date in str we will first convert into the interger

# %%
# Converting to datetime datatype
date['date'] = pd.to_datetime(date['date'])

# %%
date['date']
# Out:
# 0     2019-12-10
# 1     2018-08-15
# 2     2018-10-23
# 3     2019-08-17
# 4     2019-01-06
#          ...
# 995   2018-10-08
# 996   2018-12-06
# 997   2019-05-07
# 998   2019-03-03
# 999   2019-10-15
# Name: date, Length: 1000, dtype: datetime64[ns]

# %%
date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        1000 non-null   datetime64[ns]
#  1   product_id  1000 non-null   int64
#  2   city_id     1000 non-null   int64
#  3   orders      1000 non-null   int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 31.4 KB

# %%
# 1. extracting the year first

# %%
date['date_year'] = date['date'].dt.year

# %%
date.head(10)
# Out:
#         date  product_id  city_id  orders  date_year
# 0 2019-12-10        5628       25       3       2019
# 1 2018-08-15        3646       14     157       2018
# 2 2018-10-23        1859       25       1       2018
# 3 2019-08-17        7292       25       1       2019
# 4 2019-01-06        4344       25       3       2019
# 5 2018-08-23        1811       25       4       2018
# 6 2018-11-21        1282       26       1       2018
# 7 2019-03-27        5022        2      41       2019
# 8 2019-06-29        3699        3      15       2019
# 9 2018-08-30        4373       11       3       2018

# %%
# 2. extracting the month now

# %%
date['date_month_no'] = date['date'].dt.month

# %%
date
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no
# 0   2019-12-10        5628       25       3       2019             12
# 1   2018-08-15        3646       14     157       2018              8
# 2   2018-10-23        1859       25       1       2018             10
# 3   2019-08-17        7292       25       1       2019              8
# 4   2019-01-06        4344       25       3       2019              1
# ..         ...         ...      ...     ...        ...            ...
# 995 2018-10-08         255       13       1       2018             10
# 996 2018-12-06        5521        7       1       2018             12
# 997 2019-05-07         487       26      14       2019              5
# 998 2019-03-03        1503       21       2       2019              3
# 999 2019-10-15        6371        7      22       2019             10
#
# [1000 rows x 6 columns]

# %%
# 3. month name now

# %%
date['date_month_name'] = date['date'].dt.month_name()

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name
# 0        December
# 1          August
# 2         October
# 3          August
# 4         January

# %%
# day now

# %%
date['date_day'] = date['date'].dt.day

# %%
date.sample(20)
# Out:
#           date  product_id  city_id  orders  date_year  date_month_no  \
# 942 2019-11-16        2999        7       1       2019             11
# 669 2018-10-31        1647        4       1       2018             10
# 826 2018-09-22         944       28       1       2018              9
# 314 2018-10-06        4845       22       4       2018             10
# 290 2018-12-05        4254       16      37       2018             12
# 47  2018-12-11        3437       14       2       2018             12
# 146 2019-12-13        6828       13       1       2019             12
# 871 2018-12-26        7378       21       8       2018             12
# 597 2018-10-18        4846        1       1       2018             10
# 714 2019-08-07        4659        1       1       2019              8
# 981 2019-06-17        7526       14      12       2019              6
# 153 2019-01-13        4576       22       1       2019              1
# ...

# %%
# week now

# %%
date['date_day'] = date['date'].dt.dayofweek

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day
# 0        December         1
# 1          August         2
# 2         October         1
# 3          August         5
# 4         January         6

# %%
# day of week - name

# %%
date['date_day_name'] = date['date'].dt.day_name()
date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day date_day_name
# 0 2019-12-10       2019             12        December         1       Tuesday
# 1 2018-08-15       2018              8          August         2     Wednesday
# 2 2018-10-23       2018             10         October         1       Tuesday
# 3 2019-08-17       2019              8          August         5      Saturday
# 4 2019-01-06       2019              1         January         6        Sunday

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day date_day_name
# 0        December         1       Tuesday
# 1          August         2     Wednesday
# 2         October         1       Tuesday
# 3          August         5      Saturday
# 4         January         6        Sunday

# %%
date.head()
# Out:
#         date  product_id  city_id  orders  date_year  date_month_no  \
# 0 2019-12-10        5628       25       3       2019             12
# 1 2018-08-15        3646       14     157       2018              8
# 2 2018-10-23        1859       25       1       2018             10
# 3 2019-08-17        7292       25       1       2019              8
# 4 2019-01-06        4344       25       3       2019              1
#
#   date_month_name  date_day date_day_name
# 0        December         1       Tuesday
# 1          August         2     Wednesday
# 2         October         1       Tuesday
# 3          August         5      Saturday
# 4         January         6        Sunday

# %%
# is weekend or not 

date['date_is_weekend'] = np.where(date['date_dow_name'].isin(['Sunday', 'Saturday']), 1,0)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date_dow_name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[125], line 3
# ...

# %%
# extrct year week

# %%
date['date_week'] = date['date'].dt.isocalendar().week

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December         1         1
# 1 2018-08-15       2018              8          August         2         2
# 2 2018-10-23       2018             10         October         1         1
# 3 2019-08-17       2019              8          August         5         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name date_day_name  date_is_weekend  date_week
# 0       Tuesday       Tuesday                0         50
# 1     Wednesday     Wednesday                0         33
# 2       Tuesday       Tuesday                0         43
# 3      Saturday      Saturday                1         33
# 4        Sunday        Sunday                1          1

# %%
# quartile

# %%
date['quarter'] = date['date'].dt.quarter

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December         1         1
# 1 2018-08-15       2018              8          August         2         2
# 2 2018-10-23       2018             10         October         1         1
# 3 2019-08-17       2019              8          August         5         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name date_day_name  date_is_weekend  date_week  quarter
# 0       Tuesday       Tuesday                0         50        4
# 1     Wednesday     Wednesday                0         33        3
# 2       Tuesday       Tuesday                0         43        4
# 3      Saturday      Saturday                1         33        3
# 4        Sunday        Sunday                1          1        1

# %%
# Extract Semester
date['semester'] = np.where(date['quarter'].isin([1,2]), 1, 2)

date.drop(columns=['product_id','city_id','orders']).head()
# Out:
#         date  date_year  date_month_no date_month_name  date_day  date_dow  \
# 0 2019-12-10       2019             12        December         1         1
# 1 2018-08-15       2018              8          August         2         2
# 2 2018-10-23       2018             10         October         1         1
# 3 2019-08-17       2019              8          August         5         5
# 4 2019-01-06       2019              1         January         6         6
#
#   date_dow_name date_day_name  date_is_weekend  date_week  quarter  semester
# 0       Tuesday       Tuesday                0         50        4         2
# 1     Wednesday     Wednesday                0         33        3         2
# 2       Tuesday       Tuesday                0         43        4         2
# 3      Saturday      Saturday                1         33        3         2
# 4        Sunday        Sunday                1          1        1         1

# %% [markdown]
# # extrct time

# %%
import datetime
today = datetime.datetime.today()
today
# Out:
# datetime.datetime(2026, 3, 19, 12, 23, 47, 317940)

# %%
today - date['date']
# Out:
# 0     2291 days 12:16:10.655122
# 1     2773 days 12:16:10.655122
# 2     2704 days 12:16:10.655122
# 3     2406 days 12:16:10.655122
# 4     2629 days 12:16:10.655122
#                  ...
# 995   2719 days 12:16:10.655122
# 996   2660 days 12:16:10.655122
# 997   2508 days 12:16:10.655122
# 998   2573 days 12:16:10.655122
# 999   2347 days 12:16:10.655122
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   object
#  1   msg     1000 non-null   object
# dtypes: object(2)
# memory usage: 15.8+ KB

# %%
time.describe()
# Out:
#                        date                                          msg
# count                  1000                                         1000
# unique                  999                                          966
# top     2013-11-01 23:36:00  ласковая кошечка ищет своего ночного котика
# freq                      2                                            4

# %%
time.isnull().sum()
# Out:
# date    0
# msg     0
# dtype: int64

# %%
(today - date['date']).dt.days
# Out:
# 0      2291
# 1      2773
# 2      2704
# 3      2406
# 4      2629
#        ...
# 995    2719
# 996    2660
# 997    2508
# 998    2573
# 999    2347
# Name: date, Length: 1000, dtype: int64

# %%
# Months passed

date['months_diff'] = ((today - date['date']).dt.days // 30)

# %%
# Converting to datetime datatype
time['date'] = pd.to_datetime(time['date'])
time.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    1000 non-null   datetime64[ns]
#  1   msg     1000 non-null   object
#  2   hour    1000 non-null   int32
#  3   min     1000 non-null   int32
#  4   sec     1000 non-null   int32
#  5   time    1000 non-null   object
# dtypes: datetime64[ns](1), int32(3), object(2)
# memory usage: 35.3+ KB

# %%
time['hour'] = time['date'].dt.hour
time['min'] = time['date'].dt.minute
time['sec'] = time['date'].dt.second

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %%
# Extract Time part


time['time'] = time['date'].dt.time

time.head()
# Out:
#                  date                                                msg  \
# 0 2013-12-15 00:50:00                           ищу на сегодня мужика 37
# 1 2014-04-29 23:40:00   ПАРЕНЬ БИ ИЩЕТ ДРУГА СЕЙЧАС!! СМС ММС 0955532826
# 2 2012-12-30 00:21:00           Днепр.м 43 позн.с д/ж *.о  067.16.34.576
# 3 2014-11-28 00:31:00  КИЕВ ИЩУ Д/Ж ДО 45 МНЕ СЕЙЧАС СКУЧНО 093 629 9...
# 4 2013-10-26 23:11:00    Зая я тебя никогда не обижу  люблю тебя!)  Даше
#
#    hour  min  sec      time
# 0     0   50    0  00:50:00
# 1    23   40    0  23:40:00
# 2     0   21    0  00:21:00
# 3     0   31    0  00:31:00
# 4    23   11    0  23:11:00

# %%
# Time difference
today - time['date']
# Out:
# 0     4477 days 11:26:10.655122
# 1     4341 days 12:36:10.655122
# 2     4827 days 11:55:10.655122
# 3     4129 days 11:45:10.655122
# 4     4526 days 13:05:10.655122
#                  ...
# 995   5116 days 11:26:10.655122
# 996   4437 days 13:02:10.655122
# 997   4902 days 12:39:10.655122
# 998   5018 days 12:42:10.655122
# 999   4290 days 12:51:10.655122
# Name: date, Length: 1000, dtype: timedelta64[ns]

# %%
# in seconds

(today - time['date'])/np.timedelta64(1,'s')
# Out:
# 0      3.868540e+08
# 1      3.751078e+08
# 2      4.170957e+08
# 3      3.567879e+08
# 4      3.910935e+08
#            ...
# 995    4.420636e+08
# 996    3.834037e+08
# 997    4.235784e+08
# 998    4.336009e+08
# 999    3.707023e+08
# Name: date, Length: 1000, dtype: float64

# %%
# in minutes

(today - time['date'])/np.timedelta64(1,'m')
# Out:
# 0      6.447566e+06
# 1      6.251796e+06
# 2      6.951595e+06
# 3      5.946465e+06
# 4      6.518225e+06
#            ...
# 995    7.367726e+06
# 996    6.390062e+06
# 997    7.059639e+06
# 998    7.226682e+06
# 999    6.178371e+06
# Name: date, Length: 1000, dtype: float64

# %%
# in hours

(today - time['date'])/np.timedelta64(1,'h')
# Out:
# 0      107459.436293
# 1      104196.602960
# 2      115859.919626
# 3       99107.752960
# 4      108637.086293
#            ...
# 995    122795.436293
# 996    106501.036293
# 997    117660.652960
# 998    120444.702960
# 999    102972.852960
# Name: date, Length: 1000, dtype: float64
