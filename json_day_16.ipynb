# %%
import pandas as pd

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("train.json").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39774 entries, 0 to 39773
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           39774 non-null  int64
#  1   cuisine      39774 non-null  object
#  2   ingredients  39774 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 932.3+ KB

# %%
pd.read_json("train.json").columns
# Out:
# Index(['id', 'cuisine', 'ingredients'], dtype='object')

# %%
pd.read_json("train.json").head()
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...

# %%
pd.read_json("train.json").tail()
# Out:
#           id  cuisine                                        ingredients
# 39769  29109    irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462  italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238    irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882  chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362  mexican  [green chile, jalapeno chilies, onions, ground...

# %%
pd.read_json("train.json").head(10)
# Out:
#       id      cuisine                                        ingredients
# 0  10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1  25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2  20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3  22213       indian                [water, vegetable oil, wheat, salt]
# 4  13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# 5   6602     jamaican  [plain flour, sugar, butter, eggs, fresh ginge...
# 6  42779      spanish  [olive oil, salt, medium shrimp, pepper, garli...
# 7   3735      italian  [sugar, pistachio nuts, white almond bark, flo...
# 8  16903      mexican  [olive oil, purple onion, fresh pineapple, por...
# 9  12734      italian  [chopped tomatoes, fresh basil, garlic, extra-...

# %% [markdown]
# # json data through link
# json data can be import as url

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ...

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 166 entries, INR to ZWL
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   provider               166 non-null    object
#  1   WARNING_UPGRADE_TO_V6  166 non-null    object
#  2   terms                  166 non-null    object
#  3   base                   166 non-null    object
#  4   date                   166 non-null    datetime64[ns]
#  5   time_last_updated      166 non-null    int64
#  6   rates                  166 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 10.4+ KB

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR").columns
# Out:
# Index(['provider', 'WARNING_UPGRADE_TO_V6', 'terms', 'base', 'date',
#        'time_last_updated', 'rates'],
#       dtype='object')

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR").head()
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
#
#                                       terms base       date  \
# INR  https://www.exchangerate-api.com/terms  INR 2025-12-07
# AED  https://www.exchangerate-api.com/terms  INR 2025-12-07
# AFN  https://www.exchangerate-api.com/terms  INR 2025-12-07
# ALL  https://www.exchangerate-api.com/terms  INR 2025-12-07
# AMD  https://www.exchangerate-api.com/terms  INR 2025-12-07
#
#      time_last_updated   rates
# INR         1765065601  1.0000
# ...

# %%
pd.read_json("train.json")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("train.json", orient= "records")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
pd.read_json("train.json", orient= "object")
# Out:
#           id      cuisine                                        ingredients
# 0      10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1      25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2      20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3      22213       indian                [water, vegetable oil, wheat, salt]
# 4      13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ...      ...          ...                                                ...
# 39769  29109        irish  [light brown sugar, granulated sugar, butter, ...
# 39770  11462      italian  [KRAFT Zesty Italian Dressing, purple onion, b...
# 39771   2238        irish  [eggs, citrus fruit, raisins, sourdough starte...
# 39772  41882      chinese  [boneless chicken skinless thigh, minced garli...
# 39773   2362      mexican  [green chile, jalapeno chilies, onions, ground...
#
# [39774 rows x 3 columns]

# %%
import pandas as pd

# %%
pd.read_json("world-countries.json")
# Out:
#                   type                                           features
# 0    FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Af...
# 1    FeatureCollection  {'type': 'Feature', 'properties': {'name': 'An...
# 2    FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Al...
# 3    FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Un...
# 4    FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ar...
# ..                 ...                                                ...
# 172  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'We...
# 173  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Ye...
# 174  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'So...
# 175  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Za...
# 176  FeatureCollection  {'type': 'Feature', 'properties': {'name': 'Zi...
#
# [177 rows x 2 columns]

# %%
pd.read_json("world-countries.json").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   type      177 non-null    object
#  1   features  177 non-null    object
# dtypes: object(2)
# memory usage: 2.9+ KB

# %%
pd.read_json("test.json")
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]

# %%
pd.read_json("test.json", precise_float = True)
# Out:
#          id                                        ingredients
# 0     18009  [baking powder, eggs, all-purpose flour, raisi...
# 1     28583  [sugar, egg yolks, corn starch, cream of tarta...
# 2     41580  [sausage links, fennel bulb, fronds, olive oil...
# 3     29752  [meat cuts, file powder, smoked sausage, okra,...
# 4     35687  [ground black pepper, salt, sausage casings, l...
# ...     ...                                                ...
# 9939  30246  [large egg yolks, fresh lemon juice, sugar, bo...
# 9940  36028  [hot sauce, butter, sweet potatoes, adobo sauc...
# 9941  22339  [black pepper, salt, parmigiano reggiano chees...
# 9942  42525  [cheddar cheese, cayenne, paprika, plum tomato...
# 9943   1443  [cold water, olive oil, lime wedges, garlic cl...
#
# [9944 rows x 2 columns]
