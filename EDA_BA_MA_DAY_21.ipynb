# %%
import pandas as pd
import seaborn as sns

# %%
flights = pd.read_csv("flights.csv")

# %%
flights
# Out:
#             id  year  month  day  dep_time  sched_dep_time  dep_delay  \
# 0            0  2013      1    1     517.0             515        2.0
# 1            1  2013      1    1     533.0             529        4.0
# 2            2  2013      1    1     542.0             540        2.0
# 3            3  2013      1    1     544.0             545       -1.0
# 4            4  2013      1    1     554.0             600       -6.0
# ...        ...   ...    ...  ...       ...             ...        ...
# 336771  336771  2013      9   30       NaN            1455        NaN
# 336772  336772  2013      9   30       NaN            2200        NaN
# 336773  336773  2013      9   30       NaN            1210        NaN
# 336774  336774  2013      9   30       NaN            1159        NaN
# 336775  336775  2013      9   30       NaN             840        NaN
#
#         arr_time  sched_arr_time  arr_delay  ... flight  tailnum origin dest  \
# ...

# %%
Iris = pd.read_csv("Iris.csv")

# %%
Iris
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
titanic = pd.read_csv("train.csv")

# %%
titanic
# Out:
#        ID   W    G    R    AB     H    1B   2B  3B   HR  ...  HBP  BBHBP  SF  \
# 0       1  60  162  558  5336  1280   891  247  31  111  ...    0    460   0
# 1       3  86  161  677  5620  1492  1147  216  46   83  ...    0    531   0
# 2       5  79  162  679  5550  1496  1088  262  63   83  ...    0    543   0
# 3       7  96  162  780  5536  1458   990  265  40  163  ...    0    561   0
# 4       9  96  162  688  5441  1354   905  247  21  181  ...   55    597  35
# ..    ...  ..  ...  ...   ...   ...   ...  ...  ..  ...  ...  ...    ...  ..
# 576  1153  71  162  680  5592  1429  1037  205  29  158  ...    0    471   0
# 577  1155  76  162  750  5518  1380   871  287  28  194  ...   81    680  25
# 578  1157  83  162  836  5568  1526  1037  288  39  162  ...   75    551  57
# 579  1159  67  162  758  5517  1507  1028  278  59  142  ...    0    388   0
# 580  1161  67  162  667  5491  1353   850  311  27  165  ...   64    516  49
#
# ...

# %%
tips = pd.read_csv("tip.csv")

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# # scatter plot
# numerical to numerical data

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips , hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips,hue = 'sex',style='smoker')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(x='total_bill',y='tip', data=tips,hue = 'sex',style='smoker',size='size')
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # bar plot
# N-C

# %%
sns.barplot(x='total_bill',y='sex',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %%
sns.barplot(x='total_bill',y='sex',data=tips,hue = 'sex')
# Out:
# <Axes: xlabel='total_bill', ylabel='sex'>

# %% [markdown]
# # box plot
# n-c

# %%
sns.boxplot(x='origin' , y ='distance'  , data=flights)
# Out:
# <Axes: xlabel='origin', ylabel='distance'>

# %%
sns.boxplot(x='origin' , y ='distance'  , data=flights,hue='year')
# Out:
# <Axes: xlabel='origin', ylabel='distance'>

# %% [markdown]
# # distplot
# n-c

# %%
tit = pd.read_csv("titanic.csv")

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sns.histplot(x='Age',data=tit)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Survived',data=tit)
# Out:
# <Axes: xlabel='Survived', ylabel='Count'>

# %%
sns.histplot(x='Survived',y='Age',data=tit)
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
sns.histplot(tit[tit['Survived'] == 0]['Age'])
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Age',data=tit,hue='Survived')
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %%
sns.histplot(x='Age',data=tit,hue='Survived',kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# # heatmap
# c-c

# %%
tit.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
pd.crosstab(tit['Pclass'] ,tit['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(tit['Pclass'] ,tit['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
tit.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
pd.crosstab(tit['Pclass'],tit['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(tit['Pclass'],tit['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
tit.groupby('Pclass')['Survived'].mean()
# Out:
# Pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: Survived, dtype: float64

# %%
tit.groupby('Pclass')['Survived'].mean()*100
# Out:
# Pclass
# 1    62.962963
# 2    47.282609
# 3    24.236253
# Name: Survived, dtype: float64

# %%
tit.groupby('Age')['Survived'].mean()*100
# Out:
# Age
# 0.42     100.0
# 0.67     100.0
# 0.75     100.0
# 0.83     100.0
# 0.92     100.0
#          ...
# 70.00      0.0
# 70.50      0.0
# 71.00      0.0
# 74.00      0.0
# 80.00    100.0
# Name: Survived, Length: 88, dtype: float64

# %%
tit.groupby('Sex')['Survived'].mean()*100
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
tit.groupby('Fare')['Survived'].mean()*100
# Out:
# Fare
# 0.0000        6.666667
# 4.0125        0.000000
# 5.0000        0.000000
# 6.2375        0.000000
# 6.4375        0.000000
#                ...
# 227.5250     75.000000
# 247.5208     50.000000
# 262.3750    100.000000
# 263.0000     50.000000
# 512.3292    100.000000
# Name: Survived, Length: 248, dtype: float64

# %% [markdown]
# # clustermap
# c-c

# %%
pd.crosstab(tit['SibSp'],tit['Survived'])
# Out:
# Survived    0    1
# SibSp
# 0         398  210
# 1          97  112
# 2          15   13
# 3          12    4
# 4          15    3
# 5           5    0
# 8           7    0

# %%
sns.clustermap(pd.crosstab(tit['SibSp'],tit['Survived']))

# %%
sns.clustermap(pd.crosstab(tit['Parch'],tit['Survived']))

# %% [markdown]
# # pair plot
# n-n

# %%
Iris.head(4)
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa

# %%
sns.pairplot(Iris)

# %%
sns.pairplot(Iris,hue='Species')

# %% [markdown]
# # line plot
# n-n

# %%
flights.head()
# Out:
#    id  year  month  day  dep_time  sched_dep_time  dep_delay  arr_time  \
# 0   0  2013      1    1     517.0             515        2.0     830.0
# 1   1  2013      1    1     533.0             529        4.0     850.0
# 2   2  2013      1    1     542.0             540        2.0     923.0
# 3   3  2013      1    1     544.0             545       -1.0    1004.0
# 4   4  2013      1    1     554.0             600       -6.0     812.0
#
#    sched_arr_time  arr_delay  ... flight  tailnum origin dest air_time  \
# 0             819       11.0  ...   1545   N14228    EWR  IAH    227.0
# 1             830       20.0  ...   1714   N24211    LGA  IAH    227.0
# 2             850       33.0  ...   1141   N619AA    JFK  MIA    160.0
# 3            1022      -18.0  ...    725   N804JB    JFK  BQN    183.0
# 4             837      -25.0  ...    461   N668DN    LGA  ATL    116.0
#
#    distance  hour  minute            time_hour                    name
# ...

# %%
flights.groupby('year').sum()
