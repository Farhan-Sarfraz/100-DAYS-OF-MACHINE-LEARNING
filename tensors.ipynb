# %%
import numpy as np

# %%
x = np.array(6)

# %%
x
# Out:
# array(6)

# %%
x.ndim
# Out:
# 0

# %%
x = np.array([1,2,3,4])

# %%
x
# Out:
# array([1, 2, 3, 4])

# %%
x.ndim
# Out:
# 1

# %%
x = np.array([[1,2],[3,4]])

# %%
x
# Out:
# array([[1, 2],
#        [3, 4]])

# %%
x.ndim
# Out:
# 2

# %%
x.shape
# Out:
# (2, 2)

# %%
a = np.array([[1,2,3],[4,5,6]])

# %%
b = np.array([[5,6,2],[7,8,9]])

# %%
print("addition = ", a + b)
# Out:
# addition [[ 6  8  5]
#  [11 13 15]]
