# %%
import pandas as pd
import requests

# %% [markdown]
# # response 200 == success
# data always comes in the json format

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=714f071648a411f61de79d74f97e588d')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=714f071648a411f61de79d74f97e588d')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 21.1826,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.713,
#    'vote_count': 29325},
#   {'adult': False,
#    'backdrop_path': '/39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.sql()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 response.sql()
#
# AttributeError: 'Response' object has no attribute 'sql'

# %%
response.xlsx()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 response.xlsx()
#
# AttributeError: 'Response' object has no attribute 'xlsx'

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 21.1826,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.713,
#   'vote_count': 29325},
#  {'adult': False,
#   'backdrop_path': '/39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg          [18, 80]     238
# 2   False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]     389
# 5   False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg   [16, 10751, 14]     129
# 6   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 7   False  /zQDFHYNVVVp9OAYSixYAG1SyX1l.jpg   [35, 18, 10749]   19404
# 8   False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg      [14, 18, 80]     497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 10  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg      [53, 80, 35]     680
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     21.1826
# 1  Spanning the years 1945 to 1955, a chronicle o...     22.6603
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.713       29325
# 1  False         8.685       22131

# %%
pd.DataFrame(response.json()['results']).head(9)
# Out:
#    adult                     backdrop_path         genre_ids     id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]    278
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg          [18, 80]    238
# 2  False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg          [18, 80]    240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]    424
# 4  False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]    389
# 5  False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg   [16, 10751, 14]    129
# 6  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]    155
# 7  False  /zQDFHYNVVVp9OAYSixYAG1SyX1l.jpg   [35, 18, 10749]  19404
# 8  False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg      [14, 18, 80]    497
#
#   original_language                original_title  \
# 0                en      The Shawshank Redemption
# 1                en                 The Godfather
# 2                en         The Godfather Part II
# 3                en              Schindler's List
# ...

# %%
pd.DataFrame(response.json()['results']).head(1)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
#
#              original_title  \
# 0  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     21.1826
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False         8.713       29325

# %%
pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
# Out:
#         id  popularity                                          title  \
# 0      278     21.1826                       The Shawshank Redemption
# 1      238     22.6603                                  The Godfather
# 2      240     14.3565                          The Godfather Part II
# 3      424      9.8381                               Schindler's List
# 4      389      9.2438                                   12 Angry Men
# 5      129     14.9732                                  Spirited Away
# 6      155     24.5837                                The Dark Knight
# 7    19404      7.3493                    Dilwale Dulhania Le Jayenge
# 8      497     11.8605                                 The Green Mile
# 9   496243     19.5154                                       Parasite
# 10     122     15.5086  The Lord of the Rings: The Return of the King
# 11     680     16.3181                                   Pulp Fiction
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']].head(1)
# Out:
#     id  popularity                     title  \
# 0  278     21.1826  The Shawshank Redemption
#
#                                             overview  vote_average  \
# 0  Imprisoned in the 1940s for the double murder ...         8.713
#
#    vote_count release_date
# 0       29325   1994-09-23

# %%
df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]

# %%
df.head()
# Out:
#     id  popularity                     title  \
# 0  278     21.1826  The Shawshank Redemption
# 1  238     22.6603             The Godfather
# 2  240     14.3565     The Godfather Part II
# 3  424      9.8381          Schindler's List
# 4  389      9.2438              12 Angry Men
#
#                                             overview  vote_average  \
# 0  Imprisoned in the 1940s for the double murder ...         8.713
# 1  Spanning the years 1945 to 1955, a chronicle o...         8.685
# 2  In the continuing saga of the Corleone crime f...         8.571
# 3  The true story of how businessman Oskar Schind...         8.566
# 4  The defense and the prosecution have rested an...         8.548
#
#    vote_count release_date
# 0       29325   1994-09-23
# 1       22131   1972-03-14
# 2       13378   1974-12-20
# 3       16893   1993-12-15
# 4        9572   1957-04-10

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 526):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=714f071648a411f61de79d74f97e588d&page{i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %% [markdown]
# # starting again with new api
#
#
# here is again brief details of evrything

# %%
import pandas as pd 
import requests

# %%
requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=cbea2850354c8d016c22598035d70d78')
# Out:
# <Response [200]>

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=cbea2850354c8d016c22598035d70d78')

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 21.1826,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.713,
#    'vote_count': 29325},
#   {'adult': False,
#    'backdrop_path': '/39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
#   'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#   'popularity': 21.1826,
#   'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#   'release_date': '1994-09-23',
#   'title': 'The Shawshank Redemption',
#   'video': False,
#   'vote_average': 8.713,
#   'vote_count': 29325},
#  {'adult': False,
#   'backdrop_path': '/39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
# ...

# %%
pd.DataFrame(response.json()['results'])
# Out:
#     adult                     backdrop_path         genre_ids      id  \
# 0   False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]     278
# 1   False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg          [18, 80]     238
# 2   False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg          [18, 80]     240
# 3   False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]     424
# 4   False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]     389
# 5   False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg   [16, 10751, 14]     129
# 6   False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]     155
# 7   False  /zQDFHYNVVVp9OAYSixYAG1SyX1l.jpg   [35, 18, 10749]   19404
# 8   False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg      [14, 18, 80]     497
# 9   False  /hiKmpZMGZsrkA3cdce8a7Dpos1j.jpg      [35, 53, 18]  496243
# 10  False  /2u7zbn8EudG6kLlBzUYqP8RyFU4.jpg      [12, 14, 28]     122
# 11  False  /suaEOtk1N1sgg2MTM7oZd2cfVp3.jpg      [53, 80, 35]     680
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg  [18, 80]  278                en
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg  [18, 80]  238                en
#
#              original_title  \
# 0  The Shawshank Redemption
# 1             The Godfather
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     21.1826
# 1  Spanning the years 1945 to 1955, a chronicle o...     22.6603
#
#                         poster_path release_date                     title  \
# 0  /9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg   1994-09-23  The Shawshank Redemption
# 1  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
#
#    video  vote_average  vote_count
# 0  False         8.713       29325
# 1  False         8.685       22131

# %%
pd.DataFrame(response.json()['results']).head(9)
# Out:
#    adult                     backdrop_path         genre_ids     id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg          [18, 80]    278
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg          [18, 80]    238
# 2  False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg          [18, 80]    240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg   [18, 36, 10752]    424
# 4  False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg              [18]    389
# 5  False  /ukfI9QkU1aIhOhKXYWE9n3z1mFR.jpg   [16, 10751, 14]    129
# 6  False  /dqK9Hag1054tghRQSqLSfrkvQnA.jpg  [18, 28, 80, 53]    155
# 7  False  /zQDFHYNVVVp9OAYSixYAG1SyX1l.jpg   [35, 18, 10749]  19404
# 8  False  /b6HWTOxn1xevvyHU2K9ICvaRU6g.jpg      [14, 18, 80]    497
#
#   original_language                original_title  \
# 0                en      The Shawshank Redemption
# 1                en                 The Godfather
# 2                en         The Godfather Part II
# 3                en              Schindler's List
# ...

# %%
pd.DataFrame(response.json()['results']).head()
# Out:
#    adult                     backdrop_path        genre_ids   id  \
# 0  False  /zfbjgQE1uSd9wiPTX4VzsLi0rGG.jpg         [18, 80]  278
# 1  False  /39rtAdg3yx6IDxRg0ZLXefv0aPY.jpg         [18, 80]  238
# 2  False  /14icRpwdgpHEHxt7Cn5hr2RQEsF.jpg         [18, 80]  240
# 3  False  /zb6fM1CX41D9rF9hdgclu0peUmy.jpg  [18, 36, 10752]  424
# 4  False  /w4bTBXcqXc2TUyS5Fc4h67uWbPn.jpg             [18]  389
#
#   original_language            original_title  \
# 0                en  The Shawshank Redemption
# 1                en             The Godfather
# 2                en     The Godfather Part II
# 3                en          Schindler's List
# 4                en              12 Angry Men
#
#                                             overview  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...     21.1826
# 1  Spanning the years 1945 to 1955, a chronicle o...     22.6603
# 2  In the continuing saga of the Corleone crime f...     14.3565
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
# Out:
#         id  popularity                                          title  \
# 0      278     21.1826                       The Shawshank Redemption
# 1      238     22.6603                                  The Godfather
# 2      240     14.3565                          The Godfather Part II
# 3      424      9.8381                               Schindler's List
# 4      389      9.2438                                   12 Angry Men
# 5      129     14.9732                                  Spirited Away
# 6      155     24.5837                                The Dark Knight
# 7    19404      7.3493                    Dilwale Dulhania Le Jayenge
# 8      497     11.8605                                 The Green Mile
# 9   496243     19.5154                                       Parasite
# 10     122     15.5086  The Lord of the Rings: The Return of the King
# 11     680     16.3181                                   Pulp Fiction
# ...

# %%
pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']].head(10)
# Out:
#        id  popularity                        title  \
# 0     278     21.1826     The Shawshank Redemption
# 1     238     22.6603                The Godfather
# 2     240     14.3565        The Godfather Part II
# 3     424      9.8381             Schindler's List
# 4     389      9.2438                 12 Angry Men
# 5     129     14.9732                Spirited Away
# 6     155     24.5837              The Dark Knight
# 7   19404      7.3493  Dilwale Dulhania Le Jayenge
# 8     497     11.8605               The Green Mile
# 9  496243     19.5154                     Parasite
#
#                                             overview  vote_average  \
# 0  Imprisoned in the 1940s for the double murder ...         8.713
# 1  Spanning the years 1945 to 1955, a chronicle o...         8.685
# 2  In the continuing saga of the Corleone crime f...         8.571
# 3  The true story of how businessman Oskar Schind...         8.566
# ...

# %%
df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]

# %%
df
# Out:
#         id  popularity                                          title  \
# 0      278     21.1826                       The Shawshank Redemption
# 1      238     22.6603                                  The Godfather
# 2      240     14.3565                          The Godfather Part II
# 3      424      9.8381                               Schindler's List
# 4      389      9.2438                                   12 Angry Men
# 5      129     14.9732                                  Spirited Away
# 6      155     24.5837                                The Dark Knight
# 7    19404      7.3493                    Dilwale Dulhania Le Jayenge
# 8      497     11.8605                                 The Green Mile
# 9   496243     19.5154                                       Parasite
# 10     122     15.5086  The Lord of the Rings: The Return of the King
# 11     680     16.3181                                   Pulp Fiction
# ...

# %%
df.head()
# Out:
#     id  popularity                     title  \
# 0  278     21.1826  The Shawshank Redemption
# 1  238     22.6603             The Godfather
# 2  240     14.3565     The Godfather Part II
# 3  424      9.8381          Schindler's List
# 4  389      9.2438              12 Angry Men
#
#                                             overview  vote_average  \
# 0  Imprisoned in the 1940s for the double murder ...         8.713
# 1  Spanning the years 1945 to 1955, a chronicle o...         8.685
# 2  In the continuing saga of the Corleone crime f...         8.571
# 3  The true story of how businessman Oskar Schind...         8.566
# 4  The defense and the prosecution have rested an...         8.548
#
#    vote_count release_date
# 0       29325   1994-09-23
# 1       22131   1972-03-14
# 2       13378   1974-12-20
# 3       16893   1993-12-15
# 4        9572   1957-04-10

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
print('hello')

# %%
print('evrything is ok')
# Out:
# evrything is ok

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1, 526):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=18c4b61f54f2a57132f860b6a534f1f6&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
    df = pd.concat([df, temp_df], ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 3
#       1 for i in range(1, 526):
#       2     response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=18c4b61f54f2a57132f860b6a534f1f6&page={i}')
# ----> 3     temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
#       4     df = pd.concat([df, temp_df], ignore_index=True)
#
# KeyError: 'results'

# %%
df

# %%
for i in range(1, 526):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=18c4b61f54f2a57132f860b6a534f1f6&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
for i in range(1, 526):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=18c4b61f54f2a57132f860b6a534f1f6&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
for i in range(1, 526):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=18c4b61f54f2a57132f860b6a534f1f6&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id','popularity','title', 'overview','vote_average','vote_count','release_date']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %% [markdown]
# # evrything is ok
#
# csv file has been generated not i can also generate from rapid ai

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[98], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.to_csv('new_file.csv')
