# %% [markdown]
# # most frqnt value imputation

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('housing_dataset.csv')

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.sample(10)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 397    398          60       RL         69.0     7590   Pave   NaN      Reg
# 833    834          20       RL        100.0    10004   Pave   NaN      Reg
# 641    642          60       FV          NaN     7050   Pave   NaN      Reg
# 1191  1192         160       FV         24.0     2645   Pave  Pave      Reg
# 306    307          60       RL        116.0    13474   Pave   NaN      Reg
# 198    199          75       RM         92.0     5520   Pave   NaN      Reg
# 964    965          60       RL         80.0    11316   Pave   NaN      Reg
# 1415  1416         120       RL         51.0     3635   Pave   NaN      Reg
# 285    286         160       FV         35.0     4251   Pave  Pave      IR1
# 145    146         160       RM         24.0     2522   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# ...

# %%
df.isnull().mean() * 100
# Out:
# Id                0.000000
# MSSubClass        0.000000
# MSZoning          0.000000
# LotFrontage      17.739726
# LotArea           0.000000
#                    ...
# MoSold            0.000000
# YrSold            0.000000
# SaleType          0.000000
# SaleCondition     0.000000
# SalePrice         0.000000
# Length: 81, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df = df[['Alley','FireplaceQu','SalePrice']]

# %%
df.head()
# Out:
#   Alley FireplaceQu  SalePrice
# 0   NaN         NaN     208500
# 1   NaN          TA     181500
# 2   NaN          TA     223500
# 3   NaN          Gd     140000
# 4   NaN          TA     250000

# %%
df.isnull().mean() * 100
# Out:
# Alley          93.767123
# FireplaceQu    47.260274
# SalePrice       0.000000
# dtype: float64

# %%
df['Alley'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Alley'>

# %%
df['Alley'].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df['Alley'].mode()
# Out:
# 0    Grvl
# Name: Alley, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['Alley']=='Grvl']['SalePrice'].plot(kind='kde', ax=ax)

df[df['Alley'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with Grvl', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('Alley')
# Out:
# Text(0.5, 1.0, 'Alley')

# %%
temp = df[df['Alley']=='Grvl']['SalePrice']

# %%
temp.head()
# Out:
# 21     139400
# 79     110000
# 92     163500
# 106    100000
# 204    110000
# Name: SalePrice, dtype: int64

# %%
df['Alley'].fillna('Grvl', inplace=True)
# Out:
# C:\Users\engrf\AppData\Local\Temp\ipykernel_14380\3685339212.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Alley'].fillna('Grvl', inplace=True)

# %%
df['Alley'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Alley'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['Alley'] == 'Grvl']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('Alley')
# Out:
# Text(0.5, 1.0, 'Alley')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
df['FireplaceQu'].mode()
# Out:
# 0    Gd
# Name: FireplaceQu, dtype: object

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

df[df['FireplaceQu']=='Gd']['SalePrice'].plot(kind='kde', ax=ax)

df[df['FireplaceQu'].isnull()]['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Houses with Gd', 'Houses with NA']
ax.legend(lines, labels, loc='best')

plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
temp = df[df['FireplaceQu']=='Gd']['SalePrice']

# %%
df['FireplaceQu'] = df['FireplaceQu'].fillna('Gd')

# %%
df['FireplaceQu'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='FireplaceQu'>

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


temp.plot(kind='kde', ax=ax)

# distribution of the variable after imputation
df[df['FireplaceQu'] == 'Gd']['SalePrice'].plot(kind='kde', ax=ax, color='red')

lines, labels = ax.get_legend_handles_labels()
labels = ['Original variable', 'Imputed variable']
ax.legend(lines, labels, loc='best')

# add title
plt.title('FireplaceQu')
# Out:
# Text(0.5, 1.0, 'FireplaceQu')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='most_frequent')

# %%
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)

# %%
imputer.statistics_
# Out:
# array(['Grvl', 'Gd'], dtype=object)

# %% [markdown]
# # missing categorical imputaion  with specific key word

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv('housing_dataset.csv',usecols=['GarageQual','FireplaceQu','SalePrice'])
df.head()
# Out:
#   FireplaceQu GarageQual  SalePrice
# 0         NaN         TA     208500
# 1          TA         TA     181500
# 2          TA         TA     223500
# 3          Gd         TA     140000
# 4          TA         TA     250000

# %%
df.isnull().mean()*100
# Out:
# FireplaceQu    47.260274
# GarageQual      5.547945
# SalePrice       0.000000
# dtype: float64

# %%
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# Text(0, 0.5, 'Number of houses')

# %%
df['GarageQual'].fillna('Missing', inplace=True)
df['GarageQual'].value_counts().sort_values(ascending=False).plot.bar()
plt.xlabel('GarageQual')
plt.ylabel('Number of houses')
# Out:
# C:\Users\engrf\AppData\Local\Temp\ipykernel_14380\281376375.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['GarageQual'].fillna('Missing', inplace=True)
# Text(0, 0.5, 'Number of houses')

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(df.drop(columns=['SalePrice']),df['SalePrice'],test_size=0.2)
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(strategy='constant',fill_value='Missing')
X_train = imputer.fit_transform(X_train)
X_test = imputer.transform(X_train)
imputer.statistics_
# Out:
# C:\Users\engrf\miniconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array(['Missing', 'Missing'], dtype=object)
