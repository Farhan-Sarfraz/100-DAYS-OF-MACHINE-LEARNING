# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=1000, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0 -0.074201  0.450746   36.107082
# 1  0.099183 -1.458641  -19.997911
# 2 -1.648343  0.938720 -105.684614
# 3  1.540303  1.003502  169.419365
# 4  1.062519  0.327435   48.841070

# %%
df.shape
# Out:
# (1000, 3)

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
fig.show()

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
# Out:
# MAE 41.53484369852959

# %%
print("MSE",mean_squared_error(y_test,y_pred))
# Out:
# MSE 2575.471938859507

# %%
print("R2 score",r2_score(y_test,y_pred))
# Out:
# R2 score 0.5565607193464639

# %%
# create grid
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)

xGrid, yGrid = np.meshgrid(x, y)

# create input (final)
final = np.vstack((
    xGrid.ravel(),
    yGrid.ravel()
)).T

# prediction
z_final = lr.predict(final).reshape(10, 10)

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.add_trace(go.Surface(x = x, y = y, z =z ))

fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 3
#       1 fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')
# ----> 3 fig.add_trace(go.Surface(x = x, y = y, z =z ))
#       5 fig.show()
#
# NameError: name 'z' is not defined

# %%
lr.coef_

# %%
lr.intercept_
