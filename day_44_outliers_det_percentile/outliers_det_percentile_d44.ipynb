# %%
import pandas as pd

# %%
df = pd.read_csv("weight-height.csv")

# %%
df
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
df.shape
# Out:
# (10000, 3)

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %% [markdown]
# # trimming

# %%
# we have just removed the outliers in this case

# %%
import seaborn as sns

# %%
sns.histplot(df['Height'], kde = True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
upper_limit = df['Height'].quantile(0.99)

# %%
upper_limit
# Out:
# np.float64(74.78571507648495)

# %%
# upper limit hmari 74.78 hai

# %%
lower_limit = df['Height'].quantile(0.01)

# %%
lower_limit
# Out:
# np.float64(58.134495462372655)

# %%
new_value = df[(df['Height'] <= 74.7857900583366 ) & (df['Height'] >=58.13441158671655)]

# %%
new_value
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
new_value['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.367560
# std          3.847528
# min         54.263133
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         78.998742
# Name: Height, dtype: float64

# %%
sns.histplot(new_value['Height'], kde=True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>

# %%
sns.boxplot(new_value['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
#  we can see here in the box plot there is no outlier in new_value['Height']

# %% [markdown]
# # capping or wincarization

# %%
import numpy as np
df['Height'] =np.where(df['Height'] >= upper_limit,
                       upper_limit,
                       np.where(df['Height'] <= lower_limit,
                                lower_limit,
                                df['Height']))

# %%
df['Height']
# Out:
# 0       73.847017
# 1       68.781904
# 2       74.110105
# 3       71.730978
# 4       69.881796
#           ...
# 9995    66.172652
# 9996    67.067155
# 9997    63.867992
# 9998    69.034243
# 9999    61.944246
# Name: Height, Length: 10000, dtype: float64

# %%
df['Height'].describe()
# Out:
# count    10000.000000
# mean        66.366281
# std          3.795717
# min         58.134412
# 25%         63.505620
# 50%         66.318070
# 75%         69.174262
# max         74.785790
# Name: Height, dtype: float64

# %%
sns.boxplot(df['Height'])
# Out:
# <Axes: ylabel='Height'>

# %%
sns.histplot(df['Height'], kde= True)
# Out:
# <Axes: xlabel='Height', ylabel='Count'>
